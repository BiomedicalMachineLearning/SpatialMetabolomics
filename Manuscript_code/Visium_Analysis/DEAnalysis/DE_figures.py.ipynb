# %%
# Environment setup #
################################################################################
import os, sys
scripts_path = '/scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/'
sys.path.append(scripts_path)

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from utils import helpers as hs
hs.setUp()

from X2_DEAnalysis import DE_figure_helpers as dhs

from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

from utils.postprocessing.format import format as form

import seaborn as sb

out_plots = 'figure_components/DE_figures/'
dir_prefix = 'data/DE_out/'
data_dirs = [dir_prefix+'Pseudo_Limma_human/',
             dir_prefix+'Pseudo_Limma_mixHuman/', #NOTE, saved all genes in
                                                  # data/lcpms_all.txt for PCA
             dir_prefix+'Pseudo_Limma_mouse/']
species_ = np.array(['human', 'mix', 'mouse'])

# %%
# Merging the mix results to save as one excel #
################################################################################
i, species = 1, 'mix'
mix_dir_prefix = dir_prefix+'Pseudo_Limma_mix/'
suffixes = ['Human', 'Mouse']

split_dirs = [mix_dir_prefix.strip('/')+suffix+'/' for suffix in suffixes]
dfs = []
sheet_names = []
for j, split_dir in enumerate(split_dirs):
    up_df_ = pd.read_excel(split_dir+
               f'de_results_PseudoLimma_allGenes_mix{suffixes[j]}.xlsx',
                      sheet_name=f'{species}.treatment_up', index_col=0)
    down_df_ = pd.read_excel(split_dir+
               f'de_results_PseudoLimma_allGenes_mix{suffixes[j]}.xlsx',
                    sheet_name=f'{species}.treatment_down', index_col=0)
    dfs.extend([up_df_, down_df_])
    sheet_names.extend([f'mix_{suffixes[j]}-genes_up',
                        f'mix_{suffixes[j]}-genes_down'])

#form.writeDFsToExcelSheets(dir_prefix+'Table_S2_MixSpotsDE.xlsx',dfs, sheet_names)

# Writing dataframes to an Excel file
excel_path = dir_prefix+'Table_S2_MixSpotsDE.xlsx'
with pd.ExcelWriter(excel_path, engine='xlsxwriter') as writer:
    for df, sheet_name in zip(dfs, sheet_names):
        df.to_excel(writer, sheet_name=sheet_name)

# %%
 # Generating the volcano plots... #
################################################################################
sample_colors = {'A1_treated': 'orange', 'B1_treated': 'aquamarine',
                 'C1_untreated': 'hotpink', 'D1_untreated': 'orchid'}
de_colors = {'up': 'red', 'down': 'blue', 'not-de': 'k'}

for i, species in enumerate(species_):
    data_dir = data_dirs[i]
    sample_colors_ = dict(zip([sample+f'_{species}' for sample in sample_colors],
                              list(sample_colors.values())))
    if species == 'mix': # Since performed human/mouse gene DE separately.
        suffixes = ['Human', 'Mouse']
        split_dirs = [mix_dir_prefix.strip('/')+suffix+'/' for suffix in suffixes]
        up_df, down_df = None, None
        for j, split_dir in enumerate(split_dirs):
            up_df_ = pd.read_excel(split_dir+
                       f'de_results_PseudoLimma_allGenes_mix{suffixes[j]}.xlsx',
                              sheet_name=f'{species}.treatment_up', index_col=0)
            down_df_ = pd.read_excel(split_dir+
                       f'de_results_PseudoLimma_allGenes_mix{suffixes[j]}.xlsx',
                            sheet_name=f'{species}.treatment_down', index_col=0)
            if type(up_df)==type(None):
                up_df, down_df = up_df_, down_df_
            else:
                up_df = pd.concat([up_df, up_df_])
                down_df = pd.concat([down_df, down_df_])

            ### Making the diagnostic plots for human/mouse genes separately ###
            # Plotting the diagnostic plots #
            dhs.plot_diagnostics(split_dir, species+suffixes[j],
                                 sample_colors_, de_colors, out_plots)

    else: # For other species, all DE genes are in the one excel sheet.
        up_df = pd.read_excel(data_dir+
                              f'de_results_PseudoLimma_allGenes_{species}.xlsx',
                              sheet_name=f'{species}.treatment_up', index_col=0)
        down_df = pd.read_excel(data_dir+
                              f'de_results_PseudoLimma_allGenes_{species}.xlsx',
                            sheet_name=f'{species}.treatment_down', index_col=0)

    de_df = pd.concat([up_df, down_df])

    # Now plotting the volcano plot #
    adj_pvals = de_df.loc[:,'padj'].values
    log10_pvals = -np.log10( adj_pvals )
    logFC = de_df.loc[:,'log2FoldChange'].values

    sig_bool = adj_pvals < .05
    up_bool = np.logical_and(sig_bool, logFC>0)
    down_bool = np.logical_and(sig_bool, logFC<0)
    de_labels = np.array([' '*max([len(label) for label in ['up', 'down', 'non-de']])
                          ]*len(sig_bool))
    de_labels[up_bool] = 'up'
    de_labels[down_bool] = 'down'
    de_labels[sig_bool==False] = 'not-de'

    hs.plot_species_scatters(de_labels, log10_pvals, logFC, de_colors,
                             alpha=.4, linewidths=0,
                             out_path=out_plots+f'{species}_volcano_plot.pdf',
                             ymax=6, xlim=(-6,6))

    # Plotting the diagnostic plots #
    if species!='mix': #Already plotted diagnostics for mixHuman/mixMouse
        dhs.plot_diagnostics(data_dir, species,
                         sample_colors_, de_colors, out_plots)
# Out:
# figure_components/DE_figures/ human_volcano_plot.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ norm_density_human.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ rle_density_human.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ logFC_density_human.pdf
# figure_components/DE_figures/ logFC_avgExpr_scatter_human.pdf
# figure_components/DE_figures/ norm_density_mixHuman.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ rle_density_mixHuman.pdf
# figure_components/DE_figures/ logFC_density_mixHuman.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ logFC_avgExpr_scatter_mixHuman.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ norm_density_mixMouse.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ rle_density_mixMouse.pdf
# figure_components/DE_figures/ logFC_density_mixMouse.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ logFC_avgExpr_scatter_mixMouse.pdf
# figure_components/DE_figures/ mix_volcano_plot.pdf
# figure_components/DE_figures/ mouse_volcano_plot.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ norm_density_mouse.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ rle_density_mouse.pdf
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# /scratch/user/uqqvo1/Medulloblastoma_analysis/scripts/X2_DEAnalysis/DE_figure_helpers.py:41: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sb.distplot(val_norms, hist=False, kde=True,
# figure_components/DE_figures/ logFC_density_mouse.pdf
# figure_components/DE_figures/ logFC_avgExpr_scatter_mouse.pdf

# %%
 # PCA analysis... #
################################################################################
# Now concatentating the lcpms together to create a PCA plot #
species_lcpms = []
for i, species in enumerate(species_):
    data_dir = data_dirs[i]
    lcpms_all = pd.read_csv(data_dir + 'data/lcpms_all.txt', sep='\t')
    species_lcpms.append(lcpms_all)

con_lcpms = pd.concat(species_lcpms, axis=1)
# Filtering to genes with a positive value somewhere #
gene_bool = [False]*con_lcpms.shape[0]
for i, gene in enumerate(con_lcpms.index):
    gene_bool[i] = len(np.where(con_lcpms.values[i,:]>0)[0]) > 3
print(sum(gene_bool))
human_genes = [gene for gene in con_lcpms.index.values[gene_bool]
               if 'hg38-' in gene]
mouse_genes = [gene for gene in con_lcpms.index.values[gene_bool]
               if 'mm10-' in gene]
print(len(human_genes))
print(len(mouse_genes))
# Looks good #

######## Performing the PCA #########
scaled_values = scale(con_lcpms.values.transpose(), axis=0)

pca = PCA(n_components=3)
pca_vals = pca.fit_transform(scaled_values)
print(pca.explained_variance_ratio_) # the proportion variation explained
print(sum(pca.explained_variance_ratio_)) # almost 90% explained by first two
#pca.components_ # has the matrix of feature weights #
# con_lcpms.index.values[np.argsort(pca.components_[1,:])] # ordered genes pc1
pca_loadings = pca.components_[2,:]
order = np.argsort(-pca_loadings)
plt.scatter(list(range(len(order))), pca_loadings[order])
plt.hlines(.02, 0, 10000)
plt.vlines(800, 0, .02)
plt.show()
top_genes = con_lcpms.index.values[order][0:800]
print(top_genes)

sb.clustermap(con_lcpms.loc[top_genes,:], z_score=0)
plt.show()

treat_colors = {'treated': 'red', 'untreated': 'blue'}
treat_labels = np.array([name.split('_')[1]
                         for name in con_lcpms.columns.values])
treat_label_colors = [treat_colors[label] for label in treat_labels]

species_colors = {'human': 'dodgerblue',
                  'mouse': 'mediumseagreen', 'mix': 'gold'}
species_labels = np.array([name.split('_')[-1]
                           for name in con_lcpms.columns.values])
species_label_colors = np.array([species_colors[label]
                                 for label in species_labels])

map = {'A1': 'treated', 'B1': 'treated', 'C1': 'untreated', 'D1': 'untreated'}
sample_labels = [name.split('_')[0] for name in con_lcpms.columns.values]
sample_label_colors = np.array([sample_colors[label+f'_{map[label]}']
                                for i, label in enumerate(sample_labels)])

treat_markers = {'treated': '*', 'untreated': '.'}

dhs.pca_plot(pca, pca_vals, treat_colors, treat_labels, treat_markers,
			 species_label_colors, out_plots+'pc1_pc2_pca.pdf',)

dhs.pca_plot(pca, pca_vals, treat_colors, treat_labels, treat_markers,
			 species_label_colors, out_plots+'pc1_pc3_pca.pdf', pc2=2,)
# Out:
# 68886
# 36601
# 32285
# [0.64556823 0.3060845  0.00942209]
# 0.9610748235538872
# ['hg38-KISS1' 'hg38-SMIM32' 'hg38-EXTL1' 'hg38-LOXL4' 'hg38-PLAC8L1'
#  'hg38-IQSEC2' 'hg38-SYNPR' 'hg38-CD93' 'hg38-AC087741.1' 'hg38-CCND1'
#  'hg38-AL596257.1' 'hg38-AC013275.1' 'hg38-SSTR1' 'hg38-PPP2R2C'
#  'hg38-MFAP5' 'hg38-CHST15' 'hg38-EWSAT1' 'hg38-CELF4' 'hg38-MYT1'
#  'hg38-AC025154.2' 'hg38-HGFAC' 'hg38-PITPNM3' 'hg38-LINC01405'
#  'hg38-PRCD' 'hg38-SIL1' 'hg38-ETV4' 'hg38-LNX1' 'hg38-KY' 'hg38-MEG3'
#  'hg38-THBD' 'hg38-AQP6' 'hg38-AC148477.4' 'hg38-LINC02838' 'hg38-CEACAM1'
#  'hg38-ASIC1' 'hg38-RPH3A' 'hg38-NUDT18' 'hg38-BTBD11' 'hg38-AC018521.2'
#  'hg38-SLC18A3' 'hg38-INMT' 'hg38-AL354950.1' 'hg38-PODN' 'hg38-ANGPTL7'
#  'hg38-CDH5' 'hg38-GRIK4' 'hg38-RHOJ' 'hg38-CDH15' 'hg38-CYGB' 'hg38-ARSF'
#  'mm10-Ttr' 'hg38-CACNA1E' 'hg38-NPL' 'hg38-C1QTNF4' 'hg38-DSCAML1'
#  'hg38-RIT2' 'hg38-AC027088.2' 'hg38-GRIK3' 'hg38-LINC01284' 'hg38-BRINP2'
#  'hg38-MRGPRE' 'hg38-FNDC5' 'hg38-CREB3L1' 'hg38-AL121929.2'
#  'hg38-AC026462.5' 'hg38-GPR143' 'hg38-SNORC' 'hg38-PTPRU' 'hg38-GPNMB'
#  'hg38-STRA6' 'hg38-CX3CL1' 'hg38-AQP5' 'hg38-GLRA4' 'hg38-AC106795.3'
#  'hg38-CHRNA3' 'hg38-OTUB2' 'hg38-SH3BP5' 'hg38-GRXCR2' 'hg38-B4GALT1-AS1'
#  'hg38-SLC43A2' 'hg38-CPEB2' 'hg38-NOL3' 'hg38-PLCL1' 'hg38-GRIN3A'
#  'hg38-GATD3A' 'hg38-GCNA' 'hg38-C1S' 'hg38-MGAT3' 'hg38-TTC9B'
#  'hg38-CHI3L1' 'hg38-MIR7-3HG' 'hg38-SPOCK1' 'hg38-NR4A3' 'hg38-KCNK17'
#  'hg38-NAP1L2' 'hg38-C11orf87' 'hg38-PLGLB2' 'hg38-NNMT' 'hg38-AF235103.3'
#  'hg38-GLT1D1' 'hg38-ABHD6' 'hg38-NHSL2' 'hg38-NFASC' 'hg38-TFF3'
#  'hg38-PCP4' 'hg38-AF038458.2' 'hg38-CHRNB4' 'hg38-FBXO2' 'hg38-CD8A'
#  'hg38-PTGDS' 'hg38-LINC01053' 'hg38-SELENBP1' 'hg38-TMC6' 'mm10-Il1b'
#  'hg38-PPP2R2B' 'hg38-RHOQ' 'hg38-ARHGDIG' 'hg38-AC100803.2'
#  'hg38-LINC01914' 'hg38-CAMK2N1' 'hg38-AP004608.1' 'hg38-ELN' 'hg38-DCT'
#  'hg38-SMPDL3B' 'hg38-IFI27' 'hg38-ATP2B2' 'hg38-ZBTB16' 'hg38-AC024933.1'
#  'hg38-SRCIN1' 'hg38-TNC' 'hg38-CHST13' 'hg38-LINC02094' 'hg38-ZNF697'
#  'hg38-TMEM88' 'hg38-ADCYAP1' 'hg38-NGB' 'hg38-PLD4' 'hg38-MEG8'
#  'hg38-EPHA3' 'hg38-RIIAD1' 'hg38-CA4' 'hg38-RASD2' 'hg38-NEFM'
#  'hg38-ZNF610' 'hg38-FBLIM1' 'hg38-CCDC195' 'hg38-AC133540.1' 'hg38-APBA1'
#  'hg38-SPRN' 'hg38-MFAP2' 'hg38-TLL1' 'hg38-TMEM114' 'hg38-PDZRN4'
#  'hg38-MEG9' 'hg38-AL136964.1' 'hg38-CHADL' 'hg38-AC109361.1'
#  'hg38-SCUBE2' 'hg38-SCGB1D1' 'hg38-CLSTN2' 'hg38-OPCML' 'mm10-Slpi'
#  'hg38-PLCD4' 'hg38-KRT33B' 'hg38-TRANK1' 'hg38-OAS1' 'hg38-PLEKHG5'
#  'hg38-DNAJB2' 'hg38-GAL' 'hg38-SVOP' 'hg38-AC112236.1' 'hg38-NELL1'
#  'hg38-CFAP58' 'hg38-COL20A1' 'hg38-CXCL1' 'hg38-PLCG1-AS1' 'hg38-ANKRD24'
#  'hg38-TENM4' 'hg38-EPHB3' 'hg38-PRSS35' 'hg38-SLC9A9' 'mm10-S100a9'
#  'hg38-LINC02515' 'hg38-ZFYVE28' 'hg38-CHTF8' 'hg38-CRIP1' 'hg38-RFPL2'
#  'hg38-LINC02762' 'hg38-CXCL6' 'hg38-AC092652.1' 'hg38-PDXK' 'hg38-CELSR2'
#  'hg38-SFRP4' 'hg38-IGFN1' 'hg38-CYP11A1' 'hg38-ST8SIA2' 'hg38-PTP4A3'
#  'hg38-EGR1' 'hg38-PIK3IP1' 'hg38-CLU' 'hg38-ABLIM2' 'hg38-KIAA1324'
#  'hg38-DACT1' 'hg38-AC013724.1' 'hg38-NCF2' 'hg38-AC099398.1'
#  'hg38-LINC01833' 'hg38-AC073073.2' 'hg38-NINJ1' 'hg38-DUBR'
#  'hg38-NEUROG2' 'hg38-MYLK' 'hg38-SV2C' 'hg38-AC092353.2' 'hg38-RFTN1'
#  'hg38-FEZF2' 'hg38-SLC6A1' 'hg38-SDS' 'hg38-C10orf62' 'hg38-DPH1'
#  'hg38-LINC02516' 'hg38-UBE2Q2L' 'hg38-ATP2A3' 'hg38-CYP1B1' 'hg38-NSG2'
#  'hg38-NRP1' 'hg38-AC007130.1' 'hg38-XKR7' 'hg38-LHFPL6' 'hg38-SGIP1'
#  'hg38-MAPK12' 'hg38-ARC' 'hg38-NTRK2' 'hg38-CCDC17' 'hg38-PLAAT4'
#  'hg38-SLC7A9' 'hg38-AHNAK2' 'hg38-SAMD4A' 'hg38-CLEC18A' 'hg38-LINC02352'
#  'hg38-DIO2' 'hg38-BHMT' 'hg38-BRINP1' 'hg38-AC027020.2' 'hg38-DMTN'
#  'mm10-Ang' 'hg38-ITGA8' 'hg38-ENTPD3' 'hg38-SLC22A23' 'hg38-SCN3B'
#  'hg38-NDRG4' 'hg38-SHC3' 'hg38-CAPN3' 'hg38-NRN1L' 'hg38-GPR12'
#  'hg38-COL11A2' 'hg38-CLVS1' 'hg38-CARTPT' 'hg38-PLAAT5' 'hg38-AC093673.1'
#  'hg38-AL731769.2' 'hg38-MMP23B' 'hg38-TLR4' 'hg38-SCG2' 'hg38-HEY1'
#  'hg38-SYT2' 'hg38-SPX' 'hg38-ITGA10' 'mm10-H2-Q1' 'hg38-LINC00634'
#  'hg38-SEMA4G' 'mm10-Cutal' 'hg38-SLC2A6' 'hg38-AL590235.2' 'hg38-SPON1'
#  'mm10-Pnlip' 'hg38-SUSD2' 'hg38-IFI27L2' 'mm10-Ptges3l' 'hg38-AC116348.1'
#  'hg38-SHROOM3' 'hg38-CHRNE' 'hg38-AC244502.1' 'hg38-LINC02384'
#  'mm10-Cd101' 'hg38-LPAR3' 'hg38-FGF1' 'hg38-LINC02198' 'hg38-DGKB'
#  'hg38-MAOA' 'mm10-Hp' 'hg38-PTCHD1' 'hg38-AL031673.1' 'hg38-SLPI'
#  'hg38-IGFBP5' 'hg38-AC091078.1' 'hg38-TMEM176B' 'hg38-CASC22'
#  'mm10-Gm19705' 'hg38-FUT8-AS1' 'hg38-ACSM5' 'hg38-LINC01812' 'hg38-THBS3'
#  'hg38-SLC5A4-AS1' 'hg38-AC092720.2' 'hg38-CNTNAP4' 'hg38-NPTXR'
#  'hg38-TNP1' 'hg38-NCAN' 'hg38-PRELP' 'hg38-ASTN2' 'hg38-SCGN'
#  'hg38-C2orf91' 'hg38-AP003419.3' 'hg38-PHYHIP' 'hg38-TMEM59L'
#  'hg38-ZNF556' 'mm10-Dcaf12l2' 'hg38-AQP3' 'hg38-PGAM2' 'hg38-PPDPFL'
#  'hg38-Z93241.1' 'hg38-ADCYAP1R1' 'hg38-AP000894.2' 'hg38-MAN2B2'
#  'hg38-CADPS' 'hg38-CRYM' 'hg38-ZNF283' 'hg38-DUSP27' 'hg38-GPR146'
#  'hg38-BX276092.9' 'hg38-LINC02611' 'hg38-HCAR3' 'hg38-ASCL1'
#  'hg38-NEURL1' 'hg38-SORCS2' 'hg38-SMIM18' 'hg38-AC009652.1' 'hg38-RUBCNL'
#  'hg38-JPH3' 'hg38-RPP38-DT' 'hg38-PNCK' 'hg38-KCNH1-IT1'
#  'hg38-AC005736.1' 'hg38-NRAP' 'hg38-IL1RAPL2' 'hg38-PHEX-AS1'
#  'hg38-GPR61' 'hg38-RASGEF1A' 'hg38-LINC02538' 'hg38-PRR5'
#  'hg38-AC005479.1' 'mm10-Ggcx' 'hg38-AC006213.4' 'hg38-CRLF1' 'hg38-HECW1'
#  'hg38-MAPK11' 'hg38-EPHA4' 'hg38-RAB37' 'hg38-CACNB4' 'hg38-NAV3'
#  'mm10-Il4i1' 'hg38-LINC01983' 'hg38-CNTNAP1' 'hg38-PROC' 'hg38-AMER3'
#  'hg38-SEMA4F' 'hg38-AC005632.5' 'hg38-AC092640.1' 'mm10-Rnasel'
#  'hg38-KIF21B' 'hg38-RRAD' 'hg38-AC023300.2' 'mm10-Pappa2' 'hg38-FABP3'
#  'hg38-AC024730.1' 'hg38-GNG3' 'hg38-CACNA2D2' 'mm10-S100a8' 'mm10-Cst7'
#  'hg38-CHRDL2' 'hg38-PCDH1' 'mm10-Clec14a' 'hg38-GPCPD1' 'hg38-CHGB'
#  'mm10-Zfp57' 'hg38-PCDHB7' 'hg38-MIA' 'hg38-SLC6A11' 'hg38-GPR155'
#  'hg38-LRRC66' 'hg38-AC104117.3' 'hg38-SFXN3' 'hg38-RPRM' 'hg38-OLIG1'
#  'hg38-CMTM5' 'hg38-PABPN1L' 'hg38-AL109811.1' 'hg38-RPS6KA1'
#  'hg38-SLC4A10' 'hg38-B3GAT1' 'hg38-LINC01137' 'hg38-SOCS2' 'hg38-LEMD1'
#  'hg38-RBFOX1' 'hg38-SIX3' 'hg38-HLA-F' 'hg38-TRNP1' 'hg38-FRY'
#  'hg38-UNC79' 'hg38-MCAM' 'hg38-LOXL2' 'hg38-TPBG' 'mm10-Heyl'
#  'hg38-AP000320.1' 'hg38-JAZF1' 'hg38-PTPRH' 'hg38-AC064875.1'
#  'hg38-COL16A1' 'hg38-NMUR2' 'hg38-SHISA6' 'hg38-SPTBN5' 'hg38-KLF1'
#  'hg38-FAM219A' 'hg38-AC007262.2' 'hg38-AP000459.2' 'hg38-PWWP3B'
#  'hg38-SHISA8' 'hg38-HRK' 'hg38-FBLL1' 'hg38-CHGA' 'mm10-Shisa3'
#  'hg38-C1QTNF3' 'hg38-PURG' 'hg38-FOXL2NB' 'hg38-FLNC' 'hg38-GLRA2'
#  'hg38-CCL2' 'hg38-FRMD4B' 'hg38-RASA3' 'hg38-AC026979.4' 'hg38-CHI3L2'
#  'hg38-AL078582.1' 'mm10-Trh' 'hg38-REPS2' 'hg38-SYNM' 'hg38-FBXO6'
#  'mm10-Ctla2b' 'hg38-AL512357.1' 'hg38-FCGBP' 'hg38-HIST1H2AC'
#  'hg38-YPEL4' 'hg38-CCDC163' 'hg38-AC079610.1' 'hg38-ARHGAP27'
#  'hg38-AC012676.1' 'hg38-NMNAT2' 'hg38-PERP' 'hg38-CNTN3' 'hg38-LEMD1-DT'
#  'hg38-TVP23A' 'hg38-C11orf98' 'hg38-AC018635.2' 'hg38-HIC1' 'hg38-TF'
#  'hg38-NAMA' 'hg38-RUNDC3A' 'hg38-NRSN2-AS1' 'hg38-ZMAT4' 'hg38-LINC00964'
#  'hg38-C1RL' 'hg38-NPY1R' 'hg38-ADAMTS4' 'hg38-C2orf66' 'hg38-BHMT2'
#  'hg38-PLAU' 'mm10-Igf1' 'hg38-CFAP58-DT' 'hg38-RBM20' 'hg38-COL12A1'
#  'hg38-TMEM151A' 'hg38-CDK5R2' 'hg38-THSD7B' 'hg38-LINC01630' 'hg38-SCX'
#  'hg38-SYTL1' 'hg38-AL033527.2' 'mm10-Tacr1' 'hg38-GPD1' 'hg38-TMC3-AS1'
#  'hg38-SLC17A6' 'hg38-ST3GAL1' 'hg38-ERICH2' 'hg38-CDON' 'hg38-BEGAIN'
#  'hg38-TTN' 'mm10-Wfdc17' 'hg38-B3GALT2' 'hg38-C1orf162' 'hg38-WDR78'
#  'hg38-AL136304.1' 'hg38-DNAH6' 'hg38-MAPT-AS1' 'hg38-DAPL1'
#  'hg38-FOXN3-AS1' 'hg38-ATP8A1' 'hg38-PLA2G4C' 'hg38-WNT7B'
#  'hg38-INKA2-AS1' 'hg38-ARHGEF33' 'hg38-NRG1' 'hg38-LRRN4CL' 'hg38-SV2B'
#  'hg38-AC012625.1' 'hg38-TTR' 'hg38-FBXL2' 'hg38-IDI2-AS1' 'mm10-Pttg1'
#  'hg38-VEPH1' 'hg38-GABBR2' 'hg38-CALCRL' 'hg38-ASPHD1' 'hg38-MID2'
#  'hg38-STMN4' 'hg38-SYT13' 'mm10-Arhgap25' 'hg38-AC005498.3'
#  'hg38-TMEM255B' 'hg38-PTPRD-AS1' 'hg38-AC021087.1' 'hg38-SNCB'
#  'hg38-RAB3A' 'hg38-SYT12' 'hg38-STX1A' 'hg38-OTUD7A' 'hg38-THRA'
#  'hg38-UQCRHL' 'hg38-LINC02078' 'mm10-Cdca8' 'hg38-ELMO1' 'hg38-THBS2'
#  'mm10-Marco' 'mm10-Trbc2' 'hg38-OSBPL5' 'hg38-AKAP14' 'mm10-Gda'
#  'hg38-C1orf194' 'hg38-SCRT1' 'hg38-GIMAP8' 'hg38-ANGPTL4'
#  'hg38-AC063944.3' 'hg38-AC093495.1' 'hg38-AC004158.1' 'mm10-Slc36a2'
#  'mm10-Saa1' 'hg38-LMCD1-AS1' 'hg38-NRIP3' 'hg38-TIGD7' 'hg38-KCNMA1'
#  'hg38-AC023886.1' 'hg38-MYOM1' 'hg38-LINC01664' 'hg38-FMNL1' 'hg38-FAAH2'
#  'mm10-2900040C04Rik' 'hg38-AC022167.2' 'hg38-FAM13C' 'hg38-AGBL3'
#  'mm10-Lcn2' 'hg38-RAB17' 'hg38-AC017076.1' 'mm10-Mafa' 'hg38-KRT16'
#  'hg38-AC089999.2' 'hg38-FBXL16' 'mm10-Rbm47' 'hg38-GDPD1' 'mm10-C6'
#  'hg38-EPHX1' 'hg38-AC007292.1' 'hg38-PLXNA4' 'hg38-DNAJC3-DT'
#  'hg38-TSGA10IP' 'hg38-HHIPL1' 'hg38-GPR83' 'hg38-CABP1' 'hg38-AC097382.3'
#  'hg38-NAV2' 'mm10-Wdr86' 'hg38-TMEM38A' 'hg38-ENTPD2' 'hg38-SAMD14'
#  'mm10-Lockd' 'hg38-CCDC96' 'hg38-TMEM132B' 'mm10-Slc13a4' 'hg38-EDNRB'
#  'mm10-Slc7a7' 'hg38-AP002026.1' 'hg38-RASA4' 'mm10-Cntf' 'mm10-Wdr89'
#  'hg38-MXD1' 'hg38-SHROOM4' 'hg38-C4orf47' 'hg38-MAPT-IT1' 'mm10-Dennd1c'
#  'hg38-GPR26' 'mm10-Oxtr' 'hg38-TSPAN17' 'hg38-KCNIP2-AS1'
#  'hg38-AL031658.1' 'hg38-CELF6' 'hg38-ZNF883' 'hg38-VWDE' 'hg38-POLR2J2'
#  'hg38-GAS6' 'hg38-TSC22D3' 'hg38-JDP2' 'hg38-SLC9A3R2' 'hg38-AC023813.3'
#  'hg38-AC104463.2' 'hg38-BTBD17' 'hg38-ARSE' 'hg38-SEZ6L2' 'hg38-MCHR1'
#  'hg38-MME' 'hg38-BHLHE41' 'hg38-C8orf34' 'hg38-AC092969.1'
#  'hg38-AC073176.2' 'hg38-GDPD5' 'hg38-ATP8B4' 'hg38-SEC16B' 'hg38-ELF5'
#  'hg38-AL357079.1' 'hg38-XKR4' 'mm10-Tmem273' 'hg38-LINC02732'
#  'hg38-AL391422.4' 'hg38-ATP1B2' 'mm10-Srarp' 'hg38-AC110619.1'
#  'hg38-AL390957.1' 'hg38-AL450384.2' 'hg38-PTPRT' 'hg38-HIST1H3E'
#  'mm10-Ecel1' 'hg38-NACAD' 'hg38-C17orf100' 'hg38-AC091488.1'
#  'hg38-AL392083.2' 'hg38-SLCO1C1' 'hg38-JPH4' 'hg38-AC139795.3'
#  'hg38-AC011468.1' 'hg38-KRT39' 'hg38-SYT16' 'mm10-Serpinb6b'
#  'hg38-LINC00378' 'hg38-AL807776.1' 'hg38-RGS7BP' 'hg38-GALNT15'
#  'hg38-VGLL2' 'hg38-AC087203.3' 'hg38-FOXJ1' 'hg38-FBXO44' 'hg38-SYN1'
#  'hg38-LRRTM1' 'hg38-KRTAP16-1' 'hg38-UBAP1L' 'hg38-AL589765.5'
#  'hg38-AC091646.1' 'mm10-Adgre1' 'hg38-CDH7' 'hg38-MMP24' 'hg38-MPP2'
#  'mm10-Pira2' 'hg38-PHEX' 'hg38-FAM49A' 'hg38-SLC2A1-AS1' 'hg38-HHATL'
#  'hg38-IL34' 'hg38-LINC01763' 'hg38-CKMT2' 'mm10-Sall3' 'hg38-SLC25A18'
#  'hg38-FBXO15' 'hg38-CSDC2' 'hg38-JUP' 'hg38-NOG' 'hg38-CHRNA4'
#  'hg38-CAVIN1' 'hg38-LY86' 'hg38-BBOX1' 'hg38-PIK3R3' 'hg38-SLC16A4'
#  'hg38-COL1A1' 'hg38-KCNH5' 'hg38-AC079154.1' 'hg38-FERMT3' 'hg38-B3GALT1'
#  'hg38-AL589765.6' 'hg38-PDZD2' 'hg38-AC026801.2' 'hg38-LINC02397'
#  'hg38-LINC00951' 'hg38-COBL' 'mm10-Fetub' 'hg38-AC004129.3' 'hg38-SFRP5'
#  'hg38-DEPP1' 'hg38-TMSB15B' 'mm10-Lyz1' 'hg38-SULT4A1' 'hg38-AC100803.4'
#  'hg38-NRXN2' 'hg38-TMEM235' 'hg38-AC007786.2' 'hg38-SYT7'
#  'hg38-AC124242.1' 'hg38-DCC' 'hg38-PRUNE2' 'hg38-GAB3' 'hg38-AC016717.2'
#  'hg38-PTPRN' 'hg38-LSAMP' 'hg38-SPATA41' 'hg38-AC011451.4' 'hg38-KCTD16'
#  'hg38-COL6A1' 'hg38-DOK4' 'hg38-TTLL9' 'hg38-LINC02487' 'hg38-GAP43'
#  'hg38-LINC01971' 'hg38-PRAP1' 'mm10-Serpina3g' 'mm10-4833438C02Rik'
#  'hg38-CES5A' 'hg38-AC006504.1' 'hg38-NPAS2' 'hg38-MCF2L-AS1'
#  'hg38-AC107223.1' 'hg38-AC091057.3' 'hg38-PMEL' 'hg38-SEMA6A-AS2'
#  'hg38-ABCC12' 'mm10-Gpx3' 'hg38-NCAM2' 'hg38-LATS2' 'hg38-TSPAN9'
#  'hg38-GPD1L' 'hg38-KLF9' 'mm10-Irs3' 'hg38-ABCG4' 'hg38-TMOD1'
#  'hg38-AL109947.1' 'hg38-AL136441.1' 'mm10-Lyzl4' 'hg38-AC096642.1'
#  'hg38-PIK3IP1-AS1' 'hg38-PPP1R12A-AS1' 'hg38-GLIPR1L2' 'hg38-AC012313.7'
#  'hg38-MIR22HG' 'hg38-KLF4' 'hg38-PRPH' 'hg38-RGS3' 'hg38-SYS1'
#  'hg38-AC005899.6' 'hg38-AL024495.1' 'hg38-BX322234.1' 'hg38-ZC2HC1C'
#  'hg38-TMEM150A' 'hg38-LRP8' 'hg38-SNED1' 'hg38-CARMIL3' 'hg38-CNTNAP2'
#  'hg38-SLC1A1' 'hg38-RETREG1' 'hg38-CCDC81' 'hg38-VSIG8' 'hg38-CFAP53'
#  'mm10-Knstrn' 'mm10-Espl1' 'hg38-EPHB1' 'hg38-SYBU' 'hg38-CHRNA1'
#  'hg38-S100A2' 'hg38-EIF4E1B' 'hg38-TRIM62' 'mm10-Rtl8c' 'hg38-SPRED3'
#  'hg38-TMEM176A' 'hg38-DISP2' 'mm10-Hk3' 'hg38-ACOT1' 'hg38-PPP1R3C'
#  'hg38-AC231533.1']
# figure_components/DE_figures/ pc1_pc2_pca.pdf
# figure_components/DE_figures/ pc1_pc3_pca.pdf
